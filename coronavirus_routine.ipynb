# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import data
data = pd.read_csv("./data/time.csv")

# %%
plt.figure();
data.plot()

# %%
plt.figure();
data.plot(x='176',y={'new_test'})
